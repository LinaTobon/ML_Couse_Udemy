# %%
# !pip install transformers
# !pip install evaluate

from transformers import logging
logging.set_verbosity(logging.WARNING)
# Out:
# Requirement already satisfied: transformers in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (4.35.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.17.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: numpy>=1.17 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from transformers) (23.0)
# Requirement already satisfied: filelock in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.14.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: fsspec in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (3.3.2)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: datasets>=2.0.0 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (2.14.6)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (2023.10.0)
# Requirement already satisfied: packaging in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (4.66.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: pandas in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (1.2.5)
# Requirement already satisfied: numpy>=1.17 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (1.24.3)
# Requirement already satisfied: dill in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (0.3.7)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (0.17.3)
# Requirement already satisfied: multiprocess in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (0.70.15)
# Requirement already satisfied: xxhash in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate) (14.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate) (5.4.1)
# Requirement already satisfied: aiohttp in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate) (3.8.6)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (20.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (3.3.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: filelock in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (2021.10.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (1.26.4)
# Requirement already satisfied: pytz>=2017.3 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from pandas->evaluate) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from pandas->evaluate) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Users/linatobon/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->evaluate) (1.15.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3

# %%
import pandas as pd
from transformers import pipeline
import evaluate

# %%
df = pd.read_csv("data/car_reviews.csv",delimiter=";")

df.head()

# %%
df = pd.read_csv("data/car_reviews.csv",delimiter=";")

df.head()

# %%
reviews = df.Review.to_list()
classes = df.Class.to_list()

# %%
sentiment_pipeline = pipeline("sentiment-analysis") 
result = sentiment_pipeline(reviews)
df_result = pd.DataFrame(result)
